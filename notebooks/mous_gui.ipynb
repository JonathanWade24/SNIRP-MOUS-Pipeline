# %%
print("This notebook launcher is deprecated for GUI use.")
print("Run this from a terminal in the repository root instead:")
print("  source .venv/bin/activate")
print("  streamlit run src/mous_pipeline/gui_streamlit.py")
